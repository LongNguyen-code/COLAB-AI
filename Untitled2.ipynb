# %% [markdown]
# <a href="https://colab.research.google.com/github/LongNguyen-code/COLAB-AI/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install osmnx
# Out:
# Requirement already satisfied: osmnx in /usr/local/lib/python3.12/dist-packages (2.1.0)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from osmnx) (1.1.3)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.30 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.32.4)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.1.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (26.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->osmnx) (1.17.0)

# %%
#23.1
m = folium.Map(location=[10.7610532, 106.668358], zoom_start=13)
group_truong = folium.FeatureGroup(name="Trường học").add_to(m)
folium.Marker([10.7610532, 106.668358], popup="Đại học kinh tế TP.HCM-Cơ sở B", tooltip="Click vào").add_to(group_truong)

group_truong = folium.FeatureGroup(name="Trường học").add_to(m)
group_benhvien = folium.FeatureGroup(name='Bệnh viện').add_to(m)
group_muasamhanhchinh = folium.FeatureGroup(name='Mua sắm & Hành chính').add_to(m)

folium.Map(location=[10.7705748, 106.6699228], zoom_start=13)
folium.Marker ([10.7705748, 106.6699228], popup="Vạn Hạnh Mall", tooltip="Click vào").add_to (group_muasamhanhchinh)

folium.Map(location=[10.7691262, 106.6710121], zoom_start=13)
folium.Marker([110.7691262, 106.6710121], popup="Bệnh viện nhi đồng 1", tooltip="Click vào").add_to(group_benhvien)

folium.Map(location=[10.7550025, 106.6705345], zoom_start=13)
folium.Marker([10.7550025, 106.6705345], popup="Bệnh viện Nguyễn Tri Phương", tooltip="Click vào").add_to(group_benhvien)

folium.Map(location=[10.7601417, 106.6661562], zoom_start=13)
folium.Marker([10.7601417, 106.6661562], popup="Ủy ban nhân dân Phường 5, Quận 10", tooltip="Click vào").add_to(group_muasamhanhchinh)

folium.Map(location=[10.756251, 106.6630621], zoom_start=13)
folium.Marker([10.756251, 106.6630621], popup="Hùng Vương Plaza", tooltip="Click vào").add_to(group_muasamhanhchinh)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41132a846dc041b81ded11778787c653 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41132a846dc041b81ded11778787c653&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41132a846dc041b81ded11778787c653 = L.map(
#                 &quot;map_41132a846dc041b81ded11778787c653&quot;,
#                 {
#                     center: [10.7610532, 106.668358],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f01ff7bd1e6873d3d4f545c0cb2f5e49 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f01ff7bd1e6873d3d4f545c0cb2f5e49.addTo(map_41132a846dc041b81ded11778787c653);
#
#
#             var feature_group_5fb26b9c343d311415ad2a93b95aa500 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2ff7739d8ad4cc338bdadf263b13b568 = L.marker(
#                 [10.7610532, 106.668358],
#                 {
# }
#             ).addTo(feature_group_5fb26b9c343d311415ad2a93b95aa500);
#
#
#         var popup_8d52804865f84e4ada164854694c62e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf94e9e28e04c2b741868a918d143cb5 = $(`&lt;div id=&quot;html_bf94e9e28e04c2b741868a918d143cb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Đại học kinh tế TP.HCM-Cơ sở B&lt;/div&gt;`)[0];
#                 popup_8d52804865f84e4ada164854694c62e2.setContent(html_bf94e9e28e04c2b741868a918d143cb5);
#
#
#
#         marker_2ff7739d8ad4cc338bdadf263b13b568.bindPopup(popup_8d52804865f84e4ada164854694c62e2)
#         ;
#
#
#
#
#             marker_2ff7739d8ad4cc338bdadf263b13b568.bindTooltip(
#                 `&lt;div&gt;
#                      Click vào
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             feature_group_5fb26b9c343d311415ad2a93b95aa500.addTo(map_41132a846dc041b81ded11778787c653);
#
#
#             var feature_group_3a84ca45cba1b7cf43ab77aae482f391 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3a84ca45cba1b7cf43ab77aae482f391.addTo(map_41132a846dc041b81ded11778787c653);
#
#
#             var feature_group_9548ee17022507ec881d7d6489715225 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2730352c29f6a3a1a26b010a9e3c9b29 = L.marker(
#                 [110.7691262, 106.6710121],
#                 {
# }
#             ).addTo(feature_group_9548ee17022507ec881d7d6489715225);
#
#
#         var popup_9964f1233c317086630c73b731910728 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b0d815337e94167bbf40103cb03e926 = $(`&lt;div id=&quot;html_4b0d815337e94167bbf40103cb03e926&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bệnh viện nhi đồng 1&lt;/div&gt;`)[0];
#                 popup_9964f1233c317086630c73b731910728.setContent(html_4b0d815337e94167bbf40103cb03e926);
#
#
#
#         marker_2730352c29f6a3a1a26b010a9e3c9b29.bindPopup(popup_9964f1233c317086630c73b731910728)
#         ;
#
#
#
#
#             marker_2730352c29f6a3a1a26b010a9e3c9b29.bindTooltip(
#                 `&lt;div&gt;
#                      Click vào
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_08b0b876a3ac251eb9c9db19fd8080a0 = L.marker(
#                 [10.7550025, 106.6705345],
#                 {
# }
#             ).addTo(feature_group_9548ee17022507ec881d7d6489715225);
#
#
#         var popup_3f5548271119ee1b2c2e6e19493bda53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff4e95722578e4f025478f9ac809a847 = $(`&lt;div id=&quot;html_ff4e95722578e4f025478f9ac809a847&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bệnh viện Nguyễn Tri Phương&lt;/div&gt;`)[0];
#                 popup_3f5548271119ee1b2c2e6e19493bda53.setContent(html_ff4e95722578e4f025478f9ac809a847);
#
#
#
#         marker_08b0b876a3ac251eb9c9db19fd8080a0.bindPopup(popup_3f5548271119ee1b2c2e6e19493bda53)
#         ;
#
#
#
#
#             marker_08b0b876a3ac251eb9c9db19fd8080a0.bindTooltip(
#                 `&lt;div&gt;
#                      Click vào
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             feature_group_9548ee17022507ec881d7d6489715225.addTo(map_41132a84

# %%
#23.2
import folium
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
geolocator = Nominatim(user_agent="geoapi",timeout=10)
addresses = [
    "Ben Thanh Market, Ho Chi Minh City",
    "Tan Son Nhat Airport, Ho Chi Minh City",
    "Saigon Notre-Dame Cathedral, Ho Chi Minh City",
    "Independence Palace, Ho Chi Minh City",
    "Landmark 81, Ho Chi Minh City",
    "Bitexco Tower, Ho Chi Minh City",
    "Saigon Zoo, Ho Chi Minh City",
    "Pham Ngu Lao Street, Ho Chi Minh City",
    "Vincom Center Dong Khoi, Ho Chi Minh City",
    "Saigon Central Post Office, Ho Chi Minh City"
]
center_address = "University of Economics Ho Chi Minh City"
center_location = geolocator.geocode(center_address)
center_coords = (center_location.latitude, center_location.longitude)
m = folium.Map(location=center_coords, zoom_start=13)
folium.Marker(
    center_coords,
    popup="Trung tâm",
    icon=folium.Icon(color="red")
).add_to(m)
for addr in addresses:
    location = geolocator.geocode(addr)
    if location is None:
        print(f"Không tìm thấy: {addr}")
        continue
    coords = (location.latitude, location.longitude)
    dist = geodesic(center_coords, coords).km
    print(f"{addr}: {dist:.2f} km")
    folium.Marker(
        coords,
        popup=f"{addr}\n{dist:.2f} km",
        icon=folium.Icon(color="blue")
    ).add_to(m)
    folium.PolyLine([center_coords, coords], color="green").add_to(m)
m
# Out:
# Ben Thanh Market, Ho Chi Minh City: 1.21 km
# Tan Son Nhat Airport, Ho Chi Minh City: 5.73 km
# Saigon Notre-Dame Cathedral, Ho Chi Minh City: 0.58 km
# Independence Palace, Ho Chi Minh City: 0.66 km
# Landmark 81, Ho Chi Minh City: 3.24 km
# Bitexco Tower, Ho Chi Minh City: 1.62 km
# Saigon Zoo, Ho Chi Minh City: 1.36 km
# Pham Ngu Lao Street, Ho Chi Minh City: 1.92 km
# Vincom Center Dong Khoi, Ho Chi Minh City: 0.94 km
# Saigon Central Post Office, Ho Chi Minh City: 0.65 km
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcc6d8de2098f6dfa6b6c8b38bf4b122 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcc6d8de2098f6dfa6b6c8b38bf4b122&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcc6d8de2098f6dfa6b6c8b38bf4b122 = L.map(
#                 &quot;map_dcc6d8de2098f6dfa6b6c8b38bf4b122&quot;,
#                 {
#                     center: [10.7830141, 106.6948927],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7a1b22e2939dddbfa4e673b8d7b623e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f7a1b22e2939dddbfa4e673b8d7b623e.addTo(map_dcc6d8de2098f6dfa6b6c8b38bf4b122);
#
#
#             var marker_990459d78b8b6d67b94020288424af13 = L.marker(
#                 [10.7830141, 106.6948927],
#                 {
# }
#             ).addTo(map_dcc6d8de2098f6dfa6b6c8b38bf4b122);
#
#
#             var icon_a61b755466b191e24e7641f73bfde5ca = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9b3b53692e928a97659a26fd1f9ec135 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb340298928d21d2596c08e16c8c11c0 = $(`&lt;div id=&quot;html_cb340298928d21d2596c08e16c8c11c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Trung tâm&lt;/div&gt;`)[0];
#                 popup_9b3b53692e928a97659a26fd1f9ec135.setContent(html_cb340298928d21d2596c08e16c8c11c0);
#
#
#
#         marker_990459d78b8b6d67b94020288424af13.bindPopup(popup_9b3b53692e928a97659a26fd1f9ec135)
#         ;
#
#
#
#
#                 marker_990459d78b8b6d67b94020288424af13.setIcon(icon_a61b755466b191e24e7641f73bfde5ca);
#
#
#             var marker_b76430fe0d95ad722c19b682f1bba87f = L.marker(
#                 [10.7725301, 106.6980365],
#                 {
# }
#             ).addTo(map_dcc6d8de2098f6dfa6b6c8b38bf4b122);
#
#
#             var icon_743a89d6e9f1ce71ff7f4722a74329e6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5f56f8368b44a0b3a0e0ddf60225d1ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28b8a5d92f94e0d08d3b5c8be6ef2483 = $(`&lt;div id=&quot;html_28b8a5d92f94e0d08d3b5c8be6ef2483&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ben Thanh Market, Ho Chi Minh City 1.21 km&lt;/div&gt;`)[0];
#                 popup_5f56f8368b44a0b3a0e0ddf60225d1ce.setContent(html_28b8a5d92f94e0d08d3b5c8be6ef2483);
#
#
#
#         marker_b76430fe0d95ad722c19b682f1bba87f.bindPopup(popup_5f56f8368b44a0b3a0e0ddf60225d1ce)
#         ;
#
#
#
#
#                 marker_b76430fe0d95ad722c19b682f1bba87f.setIcon(icon_743a89d6e9f1ce71ff7f4722a74329e6);
#
#
#             var poly_line_eb4a5c832dbb0b2e63b0c45fd907a48e = L.polyline(
#                 [[10.7830141, 106.6948927], [10.7725301, 106.6980365]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dcc6d8de2098f6dfa6b6c8b38bf4b122);
#
#
#             var marker_6b9a7c38894134b185dacfb4a1097161 = L.marker(
#                 [10.8179793, 106.6562645],
#                 {
# }
#             ).addTo(map_dcc6d8de2098f6dfa6b6c8b38bf4b122);
#
#
#             var icon_14e0ea73c7eed58c87f8220b729823aa = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );

# %%
#23.3
from folium. plugins import HeatMap
import folium
donhang = [
    [10.775,106.700],
    [10.780, 106.690],
    [10.770, 106.710]
]
m = folium.Map(location=[10.775, 106.700], zoom_start=13)
HeatMap(donhang).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5ca2cba7a04842fc01c0de4cebf9ecf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5ca2cba7a04842fc01c0de4cebf9ecf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5ca2cba7a04842fc01c0de4cebf9ecf = L.map(
#                 &quot;map_b5ca2cba7a04842fc01c0de4cebf9ecf&quot;,
#                 {
#                     center: [10.775, 106.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c86f089331081d4019689c83264a60d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c86f089331081d4019689c83264a60d3.addTo(map_b5ca2cba7a04842fc01c0de4cebf9ecf);
#
#
#             var heat_map_380f87eaeaf408932b410386d444e1f3 = L.heatLayer(
#                 [[10.775, 106.7], [10.78, 106.69], [10.77, 106.71]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_380f87eaeaf408932b410386d444e1f3.addTo(map_b5ca2cba7a04842fc01c0de4cebf9ecf);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#23.5
import folium
center = [10.776, 106.700]
m = folium.Map(location=center, zoom_start=13)
for r in [3000, 5000, 10000]:
    folium. Circle(center, radius=r, fill=True).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9286d430698f14a3f8d9f29381a9c323 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9286d430698f14a3f8d9f29381a9c323&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9286d430698f14a3f8d9f29381a9c323 = L.map(
#                 &quot;map_9286d430698f14a3f8d9f29381a9c323&quot;,
#                 {
#                     center: [10.776, 106.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f50f03a41cc66a7125d4a18cb5321527 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f50f03a41cc66a7125d4a18cb5321527.addTo(map_9286d430698f14a3f8d9f29381a9c323);
#
#
#             var circle_16bc77649a6bb1b291f91400430b723f = L.circle(
#                 [10.776, 106.7],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9286d430698f14a3f8d9f29381a9c323);
#
#
#             var circle_7b454324d40d689e8dadbd08de859683 = L.circle(
#                 [10.776, 106.7],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9286d430698f14a3f8d9f29381a9c323);
#
#
#             var circle_08b73d8d73f9c6fde9977eb6c3e79512 = L.circle(
#                 [10.776, 106.7],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9286d430698f14a3f8d9f29381a9c323);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# !pip install osmnx
# Out:
# Collecting osmnx
#   Downloading osmnx-2.1.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: geopandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from osmnx) (1.1.3)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.0.2)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.2.2)
# Requirement already satisfied: requests>=2.30 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.32.4)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from osmnx) (2.1.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (26.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->osmnx) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.30->osmnx) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->osmnx) (1.17.0)
# Downloading osmnx-2.1.0-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: osmnx
# Successfully installed osmnx-2.1.0

# %%
#23.6
import osmnx as ox
import networkx as nx
G = ox.graph_from_place("District 1, Ho Chi Minh City, Vietnam",network_type="drive")
ox.plot_graph(G)
print("Số nút giao thông:", len(G.nodes))
edges = ox.graph_to_gdfs(G, nodes=False)
print("Chiều dài đường trung bình (m):", edges["length"].mean())
# Out:
# Số nút giao thông: 989
# Chiều dài đường trung bình (m): 79.02857533456734

# %%
#23.7
import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt
G = ox.graph_from_place("District 1, Ho Chi Minh City, Vietnam", network_type="drive")
orig = ox.geocode("Ben Thanh Market, Ho Chi Minh City, Vietnam")
dest = ox.geocode("Tan Son Nhat Airport, Ho Chi Minh City, Vietnam")
orig_node = ox.distance.nearest_nodes(G, X=orig[1], Y=orig[0])
dest_node = ox.distance.nearest_nodes(G, X=dest[1], Y=dest[0])
route = nx.shortest_path(G, orig_node, dest_node, weight="length")
fig, ax = ox.plot_graph_route(G, route, route_color="red", route_linewidth=3)
plt.show()

# %%
#23.8
from geopy.distance import distance

import folium
driver = (10.779, 106.686)
customers = {
    "A": (10.775, 106.702),
    "B": (10.754, 106.665),
    "C": (10.803, 106.714)
}
nearest = min(customers.items(), key=lambda x: distance(driver, x[1]).km)
m = folium.Map(location=driver, zoom_start=13)
folium.Marker(
    driver,
    popup="Driver",
    icon=folium.Icon(color="red")
).add_to(m)
for name, coord in customers.items():
    d = distance(driver, coord).km
    folium.Marker(
        coord,
        popup=f"{name}: {d:.2f} km",
        icon=folium.Icon(color="blue")
    ).add_to(m)
    color = "green" if name == nearest[0] else "red"
    folium.PolyLine(
        [driver, coord],
        color=color,
        weight=5 if name == nearest[0] else 2
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a0b60d90d151ba94d936794e850b187 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a0b60d90d151ba94d936794e850b187&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a0b60d90d151ba94d936794e850b187 = L.map(
#                 &quot;map_4a0b60d90d151ba94d936794e850b187&quot;,
#                 {
#                     center: [10.779, 106.686],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eae6e5f4b3aedf89775bfbd0ae59e155 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eae6e5f4b3aedf89775bfbd0ae59e155.addTo(map_4a0b60d90d151ba94d936794e850b187);
#
#
#             var marker_d23fcfe929d70a7927a33888d1703dce = L.marker(
#                 [10.779, 106.686],
#                 {
# }
#             ).addTo(map_4a0b60d90d151ba94d936794e850b187);
#
#
#             var icon_73890798af9b345aa691944e0f48ad11 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_aba94b12b0a74cf92f0e522a02daeb98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fdc509bda4b415456136f833273bf37 = $(`&lt;div id=&quot;html_7fdc509bda4b415456136f833273bf37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Driver&lt;/div&gt;`)[0];
#                 popup_aba94b12b0a74cf92f0e522a02daeb98.setContent(html_7fdc509bda4b415456136f833273bf37);
#
#
#
#         marker_d23fcfe929d70a7927a33888d1703dce.bindPopup(popup_aba94b12b0a74cf92f0e522a02daeb98)
#         ;
#
#
#
#
#                 marker_d23fcfe929d70a7927a33888d1703dce.setIcon(icon_73890798af9b345aa691944e0f48ad11);
#
#
#             var marker_677ddecfce94196c2421ca540e129fd5 = L.marker(
#                 [10.775, 106.702],
#                 {
# }
#             ).addTo(map_4a0b60d90d151ba94d936794e850b187);
#
#
#             var icon_720eb974390c8f95606a6ee09df13f7b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b8fc6495e19a05e958c58881586705f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4794fc32dfd066ce0c2eda8a9a4e0e2d = $(`&lt;div id=&quot;html_4794fc32dfd066ce0c2eda8a9a4e0e2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: 1.80 km&lt;/div&gt;`)[0];
#                 popup_b8fc6495e19a05e958c58881586705f5.setContent(html_4794fc32dfd066ce0c2eda8a9a4e0e2d);
#
#
#
#         marker_677ddecfce94196c2421ca540e129fd5.bindPopup(popup_b8fc6495e19a05e958c58881586705f5)
#         ;
#
#
#
#
#                 marker_677ddecfce94196c2421ca540e129fd5.setIcon(icon_720eb974390c8f95606a6ee09df13f7b);
#
#
#             var poly_line_d4deabfa8800c82f2dd79b27dd2dbe03 = L.polyline(
#                 [[10.779, 106.686], [10.775, 106.702]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_4a0b60d90d151ba94d936794e850b187);
#
#
#             var marker_cff2a52dfe01b41127a30ef2bb0ec1ce = L.marker(
#                 [10.754, 106.665],
#                 {
# }
#             ).addTo(map_4a0b60d90d151ba94d936794e850b187);
#
#
#             var icon_92f431a907cc14dcb04cdc897fb5b4b2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0449fb61ea09da5b16ecf720929c460a = L.popup({
#   &quot;maxWidth&quot;

# %%
#23.9
from geopy.distance import distance
import folium
driver=(10.770, 106.690)
customers={
    "C1": (10.775, 106.700),
    "C2": (10.760, 106.680),
    "C3": (10.768, 106.695)
}
m=folium.Map(location=driver, zoom_start=13)
folium.Marker(
    driver,
    popup="Driver",
    icon=folium.Icon(color="red")
).add_to(m)
nearest=min(customers.items(), key=lambda x: distance(driver, x[1]).km)
for c_name, c_coord in customers.items():
    d=distance(driver, c_coord).km
    folium.Marker(
        c_coord,
        popup=f"{c_name}: {d:.2f} km",
        icon=folium.Icon(color="blue")
    ).add_to(m)
    color = "green" if c_name == nearest[0] else "gray"
    folium.PolyLine(
        [driver, c_coord],
        color=color,
        weight=5 if c_name == nearest[0] else 2
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4411fa662c4b13b6adaabd1752c27fbb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4411fa662c4b13b6adaabd1752c27fbb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4411fa662c4b13b6adaabd1752c27fbb = L.map(
#                 &quot;map_4411fa662c4b13b6adaabd1752c27fbb&quot;,
#                 {
#                     center: [10.77, 106.69],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b1ca7aee01298aaa2888fb3723e758b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1b1ca7aee01298aaa2888fb3723e758b.addTo(map_4411fa662c4b13b6adaabd1752c27fbb);
#
#
#             var marker_f320cf79439885c30454cb1cf9f23c2f = L.marker(
#                 [10.77, 106.69],
#                 {
# }
#             ).addTo(map_4411fa662c4b13b6adaabd1752c27fbb);
#
#
#             var icon_ce68cf4d04a8ddd22f6f3590a1506152 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4d7e33a8bd7018fd455f25f2443c9015 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e3ad33542f28562dd45d2cf397c3f18 = $(`&lt;div id=&quot;html_2e3ad33542f28562dd45d2cf397c3f18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Driver&lt;/div&gt;`)[0];
#                 popup_4d7e33a8bd7018fd455f25f2443c9015.setContent(html_2e3ad33542f28562dd45d2cf397c3f18);
#
#
#
#         marker_f320cf79439885c30454cb1cf9f23c2f.bindPopup(popup_4d7e33a8bd7018fd455f25f2443c9015)
#         ;
#
#
#
#
#                 marker_f320cf79439885c30454cb1cf9f23c2f.setIcon(icon_ce68cf4d04a8ddd22f6f3590a1506152);
#
#
#             var marker_a0dba1ee70730a870be374a4c5f69fb9 = L.marker(
#                 [10.775, 106.7],
#                 {
# }
#             ).addTo(map_4411fa662c4b13b6adaabd1752c27fbb);
#
#
#             var icon_60b46f8917aed6af46bb09eb99f89cc6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_db572219543818d53f95a9b5c55a41cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef20466d1aaeb6b848427fa123d69c8b = $(`&lt;div id=&quot;html_ef20466d1aaeb6b848427fa123d69c8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;C1: 1.23 km&lt;/div&gt;`)[0];
#                 popup_db572219543818d53f95a9b5c55a41cb.setContent(html_ef20466d1aaeb6b848427fa123d69c8b);
#
#
#
#         marker_a0dba1ee70730a870be374a4c5f69fb9.bindPopup(popup_db572219543818d53f95a9b5c55a41cb)
#         ;
#
#
#
#
#                 marker_a0dba1ee70730a870be374a4c5f69fb9.setIcon(icon_60b46f8917aed6af46bb09eb99f89cc6);
#
#
#             var poly_line_4720c211e04c7ac52d61ed552be67757 = L.polyline(
#                 [[10.77, 106.69], [10.775, 106.7]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_4411fa662c4b13b6adaabd1752c27fbb);
#
#
#             var marker_d412bb90f343e7137171e1728d7f9827 = L.marker(
#                 [10.76, 106.68],
#                 {
# }
#             ).addTo(map_4411fa662c4b13b6adaabd1752c27fbb);
#
#
#             var icon_02a722cf5db09c363675ebb63d677c80 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2691ae7cf6aa4e49dfec261fc7f4d1b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&

# %%
#23.10
import folium
roads = [
    {"name": "Nguyễn Huệ", "coord": (10.77411, 106.70361), "traffic": 85},
    {"name": "Lê Lợi", "coord": (10.77412, 106.70047), "traffic": 55},
    {"name": "Nam Kỳ Khởi Nghĩa", "coord": (10.78061, 106.69393), "traffic": 35},
    {"name": "Điện Biên Phủ", "coord": (10.78865, 106.69553), "traffic": 90}
]
def risk_level(traffic):
    if traffic > 70:
        return "High", "red"
    elif traffic > 40:
        return "Medium", "orange"
    else:
        return "Low", "green"
m = folium.Map(location=[10.77411, 106.70361], zoom_start=14)
for r in roads:
    level, color = risk_level(r["traffic"])
    folium.CircleMarker(
        location=r["coord"],
        radius=10,
        color=color,
        fill=True,
        fill_color=color,
        popup=f"{r['name']} - {level}"
    ).add_to(m)
main_route=[
    (10.77411, 106.70361),
    (10.78865, 106.69553)
]
folium.PolyLine(
    main_route,
    color="red",
    weight=5,
    popup="Đường tắc"
).add_to(m)
alt_route = [
    (10.77411, 106.70361),
    (10.78061, 106.69393)
]
folium.PolyLine(
    alt_route,
    color="blue",
    weight=5,
    popup="Đường đề xuất"
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b1162067cf1da5c4897d4510cf0702e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b1162067cf1da5c4897d4510cf0702e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b1162067cf1da5c4897d4510cf0702e = L.map(
#                 &quot;map_4b1162067cf1da5c4897d4510cf0702e&quot;,
#                 {
#                     center: [10.77411, 106.70361],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f3b9a60633df56cdf4a1048285ae16e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f3b9a60633df56cdf4a1048285ae16e.addTo(map_4b1162067cf1da5c4897d4510cf0702e);
#
#
#             var circle_marker_57e743988ec64e6ea904beb44a878b6a = L.circleMarker(
#                 [10.77411, 106.70361],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4b1162067cf1da5c4897d4510cf0702e);
#
#
#         var popup_49dcd1c114f037f63857e1d336a76beb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37305c6042d6fefc342151a27d436a1b = $(`&lt;div id=&quot;html_37305c6042d6fefc342151a27d436a1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nguyễn Huệ - High&lt;/div&gt;`)[0];
#                 popup_49dcd1c114f037f63857e1d336a76beb.setContent(html_37305c6042d6fefc342151a27d436a1b);
#
#
#
#         circle_marker_57e743988ec64e6ea904beb44a878b6a.bindPopup(popup_49dcd1c114f037f63857e1d336a76beb)
#         ;
#
#
#
#
#             var circle_marker_f4137b4c5a05a4aab052cd2b8a41ada5 = L.circleMarker(
#                 [10.77412, 106.70047],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4b1162067cf1da5c4897d4510cf0702e);
#
#
#         var popup_6b1f748ae08504ab0828a0e085ed8f68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23dc7c0341e232db3c14bc425fa603a1 = $(`&lt;div id=&quot;html_23dc7c0341e232db3c14bc425fa603a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lê Lợi - Medium&lt;/div&gt;`)[0];
#                 popup_6b1f748ae08504ab0828a0e085ed8f68.setContent(html_23dc7c0341e232db3c14bc425fa603a1);
#
#
#
#         circle_marker_f4137b4c5a05a4aab052cd2b8a41ada5.bindPopup(popup_6b1f748ae08504ab0828a0e085ed8f68)
#         ;
#
#
#
#
#             var circle_marker_36b4bcbfddeb4c68463e878bf474cb97 = L.circleMarker(
#                 [10.78061, 106.69393],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4b1162067cf1da5c4897d4510cf0702e);
#
#
#         var popup_d2573ecbb60deb47e8ecad26aa3d730e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb843b84a5e70ac78df353b3850c1d84 = $(`&lt;div id=&quot;html_eb843b84a5e70ac78df353b3850c1d84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nam Kỳ Khởi Nghĩa - Low&lt;/div&gt;`)[0];
#                 popup_d2573ecbb60deb47e8ecad26aa3d730e.setContent(html_eb843b84a5e70ac78df353b3850c1d84);
#
#
#
#         circle_marker_36b4bcbfddeb4c68463e878bf474cb97.bindPopup(popup_d2573ecbb60deb47e8ecad26aa3d730e)
#         ;
#
#
#
#
#             var circle_marker_e488f64988f9c51050716542864d

# %%
#23.11
import pandas as pd
import folium
from sklearn.linear_model import LinearRegression
data = {
    "Area": ["A", "A", "A", "B", "B", "B", "C", "C", "C"],
    "Hour": [8, 12, 18, 8, 12, 18, 8, 12, 18],
    "Demand": [50, 80, 120, 30, 60, 90, 20, 40, 70]
}
df = pd.DataFrame(data)
df["Area_code"] = df["Area"].map({"A": 0, "B": 1, "C": 2})
X = df[["Area_code", "Hour"]]
y = df["Demand"]
model = LinearRegression()
model.fit(X, y)
future = pd.DataFrame({
    "Area_code": [0, 1, 2],
    "Hour": [20, 20, 20]
})
pred = model.predict(future)
coords = {
    "A": (10.770, 106.690),
    "B": (10.760, 106.680),
    "C": (10.775, 106.700)
}
m = folium.Map(location=[10.770, 106.690], zoom_start=13)
areas = ["A", "B", "C"]
for i, area in enumerate(areas):
    demand = pred[i]
    if demand > 100:
        color = "red"
    elif demand > 60:
        color = "orange"
    else:
        color = "green"
    folium.CircleMarker(
        location=coords[area],
        radius=10,
        color=color,
        fill=True,
        fill_color=color,
        popup=f"{area}: {demand:.2f}"
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_693019a6386a002d51c75ae80d92ed8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_693019a6386a002d51c75ae80d92ed8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_693019a6386a002d51c75ae80d92ed8f = L.map(
#                 &quot;map_693019a6386a002d51c75ae80d92ed8f&quot;,
#                 {
#                     center: [10.77, 106.69],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b20589e9b5f3d3d02aa8ed8899cd6c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b20589e9b5f3d3d02aa8ed8899cd6c7.addTo(map_693019a6386a002d51c75ae80d92ed8f);
#
#
#             var circle_marker_164f68538ea7be93b23f527cd3bbe603 = L.circleMarker(
#                 [10.77, 106.69],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_693019a6386a002d51c75ae80d92ed8f);
#
#
#         var popup_6bad4e4618c6a2a115e053e9ce09c115 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8d3913af98fd9b5d86f9ca3193a87bd = $(`&lt;div id=&quot;html_a8d3913af98fd9b5d86f9ca3193a87bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A: 125.96&lt;/div&gt;`)[0];
#                 popup_6bad4e4618c6a2a115e053e9ce09c115.setContent(html_a8d3913af98fd9b5d86f9ca3193a87bd);
#
#
#
#         circle_marker_164f68538ea7be93b23f527cd3bbe603.bindPopup(popup_6bad4e4618c6a2a115e053e9ce09c115)
#         ;
#
#
#
#
#             var circle_marker_b0b5cd58a968a7b5927e3ce8225f4b98 = L.circleMarker(
#                 [10.76, 106.68],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_693019a6386a002d51c75ae80d92ed8f);
#
#
#         var popup_18155467ae23a5dfcaf64ad5224c62fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39903dc8d41dd3ec72b5178983644c55 = $(`&lt;div id=&quot;html_39903dc8d41dd3ec72b5178983644c55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B: 105.96&lt;/div&gt;`)[0];
#                 popup_18155467ae23a5dfcaf64ad5224c62fc.setContent(html_39903dc8d41dd3ec72b5178983644c55);
#
#
#
#         circle_marker_b0b5cd58a968a7b5927e3ce8225f4b98.bindPopup(popup_18155467ae23a5dfcaf64ad5224c62fc)
#         ;
#
#
#
#
#             var circle_marker_428c7607618a43784c9cb5165eb490e8 = L.circleMarker(
#                 [10.775, 106.7],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_693019a6386a002d51c75ae80d92ed8f);
#
#
#         var popup_59850b9c1880f3759497e971f6b4470d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a5ee2bd45ebe7814760cb6c09e6bd70 = $(`&lt;div id=&quot;html_9a5ee2bd45ebe7814760cb6c09e6bd70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;C: 85.96&lt;/div&gt;`)[0];
#                 popup_59850b9c1880f3759497e971f6b4470d.setContent(html_9a5ee2bd45ebe7814760cb6c09e6bd70);
#
#
#
#         circle_marker_428c7607618a43784c9cb5165eb490e8.bindPopup(popup_59850b9c1880f3759497e971f6b4470d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" all

# %%
#23.12
from geopy.distance import distance
import folium
depots = {
    "D1": (10.770, 106.690),
    "D2": (10.760, 106.680)
}
customers = {
    "C1": (10.775, 106.700),
    "C2": (10.762, 106.685),
    "C3": (10.768, 106.695),
    "C4": (10.758, 106.678)
}
def total_distance(route):
    dist = 0
    for i in range(len(route) - 1):
        dist += distance(route[i], route[i + 1]).km
    return dist
clusters = {d: [] for d in depots}
for c_name, c_coord in customers.items():
    nearest_depot = min(
        depots.items(),
        key=lambda x: distance(c_coord, x[1]).km
    )
    clusters[nearest_depot[0]].append((c_name, c_coord))
routes_opt = {}
for d_name, d_coord in depots.items():
    points = clusters[d_name][:]
    route = [d_coord]
    current = d_coord
    while points:
        nearest = min(
            points,
            key=lambda x: distance(current, x[1]).km
        )
        route.append(nearest[1])
        current = nearest[1]
        points.remove(nearest)
    routes_opt[d_name] = route
routes_naive = {}
for d_name, d_coord in depots.items():
    route = [d_coord] + [c[1] for c in clusters[d_name]]
    routes_naive[d_name] = route
opt_total = sum(total_distance(r) for r in routes_opt.values())
naive_total = sum(total_distance(r) for r in routes_naive.values())
print("Tổng quãng đường tối ưu:", opt_total)
print("Tổng quãng đường không tối ưu:", naive_total)
m = folium.Map(location=[10.770, 106.690], zoom_start=13)
for d_name, coord in depots.items():
    folium.Marker(
        coord,
        popup=d_name,
        icon=folium.Icon(color="red")
    ).add_to(m)
for c_name, coord in customers.items():
    folium.Marker(
        coord,
        popup=c_name,
        icon=folium.Icon(color="blue")
    ).add_to(m)
for route in routes_opt.values():
    folium.PolyLine(route, color="green", weight=5).add_to(m)
for route in routes_naive.values():
    folium.PolyLine(route, color="red", weight=2).add_to(m)
m
# Out:
# Tổng quãng đường tối ưu: 2.733236774941018
# Tổng quãng đường không tối ưu: 3.64772516361514
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92f24d3b201ff91c9e359c6987ed677f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92f24d3b201ff91c9e359c6987ed677f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92f24d3b201ff91c9e359c6987ed677f = L.map(
#                 &quot;map_92f24d3b201ff91c9e359c6987ed677f&quot;,
#                 {
#                     center: [10.77, 106.69],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a222fdbc76271b7595b729a4e93dbcb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a222fdbc76271b7595b729a4e93dbcb.addTo(map_92f24d3b201ff91c9e359c6987ed677f);
#
#
#             var marker_2bb658a1a81fff0ee55a1d4756d3695b = L.marker(
#                 [10.77, 106.69],
#                 {
# }
#             ).addTo(map_92f24d3b201ff91c9e359c6987ed677f);
#
#
#             var icon_a4cd90cb2a0d1ccc014078549b962557 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9f2b03b78ec96d1a5f75be2be8cfaced = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3de45c27659b0178739e3c86d576ce3 = $(`&lt;div id=&quot;html_f3de45c27659b0178739e3c86d576ce3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;D1&lt;/div&gt;`)[0];
#                 popup_9f2b03b78ec96d1a5f75be2be8cfaced.setContent(html_f3de45c27659b0178739e3c86d576ce3);
#
#
#
#         marker_2bb658a1a81fff0ee55a1d4756d3695b.bindPopup(popup_9f2b03b78ec96d1a5f75be2be8cfaced)
#         ;
#
#
#
#
#                 marker_2bb658a1a81fff0ee55a1d4756d3695b.setIcon(icon_a4cd90cb2a0d1ccc014078549b962557);
#
#
#             var marker_130c17c842276a5008bc2579fe4b7c7c = L.marker(
#                 [10.76, 106.68],
#                 {
# }
#             ).addTo(map_92f24d3b201ff91c9e359c6987ed677f);
#
#
#             var icon_7340bdfa0e804b182bd3e422c2c89fcd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_10d8e8eb31e14fd9f11e314a3cd163d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8469d56b46ff227e2891e17fe638dd6 = $(`&lt;div id=&quot;html_c8469d56b46ff227e2891e17fe638dd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;D2&lt;/div&gt;`)[0];
#                 popup_10d8e8eb31e14fd9f11e314a3cd163d9.setContent(html_c8469d56b46ff227e2891e17fe638dd6);
#
#
#
#         marker_130c17c842276a5008bc2579fe4b7c7c.bindPopup(popup_10d8e8eb31e14fd9f11e314a3cd163d9)
#         ;
#
#
#
#
#                 marker_130c17c842276a5008bc2579fe4b7c7c.setIcon(icon_7340bdfa0e804b182bd3e422c2c89fcd);
#
#
#             var marker_597118bd7f513df436083d28692cfcd0 = L.marker(
#                 [10.775, 106.7],
#                 {
# }
#             ).addTo(map_92f24d3b201ff91c9e359c6987ed677f);
#
#
#             var icon_a7df959756aace5f23d53e3c6f421ede = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_eb46919b47fc76f97c0fca18f7a7cc12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8ac87b13c61483d8f4ec6b4136fb658 = $(`&lt;div id=&quot;html_c8ac87b13c61483d8f4ec6b4136fb658&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;C1&lt;/div&gt;`)[0];
#                 popup_eb46919b47fc76f97c0fca18f7a7cc12.setContent(html_c8ac87b13c61483d8f4ec6b4136fb658);
#
#
#
#         marker_597118bd7f513df436083d28692cfcd0.bindPopup(popup_eb46919b47fc76f97c0fca18f7a7cc12)
#         ;
#
#
#
#
#                 marker_597118bd7f513df436083d28692cfcd0.setIcon(icon_a7df959756aace5f23d53e3c6f421ede);
#
#
#             var marker_919dce7f49c4ce7fd97a66418282f015 = L.marker(
#                 [10.762, 106.685],

# %%
#23.13
import folium
from folium.plugins import MarkerCluster, Fullscreen, MeasureControl
import pandas as pd
dc_coords = (10.7758, 106.7009)
data = {
    "ID": ["C001", "C002", "C003", "C004", "C005"],
    "Name": ["Siêu thị A", "Cửa hàng B", "Đại lý C", "Kho vệ tinh D", "Trung tâm E"],
    "Lat": [10.7626, 10.7850, 10.8000, 10.7500, 10.8200],
    "Lon": [106.6602, 106.6950, 106.7500, 106.7200, 106.7000],
    "Volume": [500, 200, 800, 1200, 450]
}
df = pd.DataFrame(data)
m = folium.Map(location=dc_coords, zoom_start=12, tiles="cartodbpositron")
Fullscreen().add_to(m)
MeasureControl().add_to(m)
fg_dc = folium.FeatureGroup(name="Kho Tổng & Vùng Phục Vụ")
folium.Marker(
    location=dc_coords,
    popup="<b>KHO TỔNG TRUNG TÂM</b>",
    icon=folium.Icon(color="red", icon="home", prefix="fa")
).add_to(fg_dc)
folium.Circle(
    location=dc_coords,
    radius=5000,
    color="red",
    fill=True,
    fill_opacity=0.1,
    tooltip="Vùng phục vụ 5km"
).add_to(fg_dc)
fg_dc.add_to(m)
fg_customers = folium.FeatureGroup(name="Mạng Lưới Khách Hàng")
marker_cluster = MarkerCluster().add_to(fg_customers)
for _, row in df.iterrows():
    if row["Volume"] >= 1000:
        color_node = "darkred"
    elif row["Volume"] >= 500:
        color_node = "orange"
    else:
        color_node = "green"
    folium.Marker(
        location=[row["Lat"], row["Lon"]],
        popup=f"<b>{row['Name']}</b><br>Sản lượng: {row['Volume']} kiện/ngày",
        icon=folium.Icon(color=color_node, icon="shopping-cart", prefix="fa")
    ).add_to(marker_cluster)
fg_customers.add_to(m)
fg_routes = folium.FeatureGroup(name="Tuyến Vận Tải")
route_points = [
    dc_coords,
    (10.7500, 106.7200)
]
folium.PolyLine(
    locations=route_points,
    color="blue",
    weight=5,
    opacity=0.6,
    dash_array="10"
).add_to(fg_routes)
fg_routes.add_to(m)
folium.LayerControl(collapsed=False).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46343aa01b59317003e69738eaa1abba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46343aa01b59317003e69738eaa1abba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46343aa01b59317003e69738eaa1abba = L.map(
#                 &quot;map_46343aa01b59317003e69738eaa1abba&quot;,
#                 {
#                     center: [10.7758, 106.7009],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e77681d27a8a5ff18e56417cd00bcc20 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e77681d27a8a5ff18e56417cd00bcc20.addTo(map_46343aa01b59317003e69738eaa1abba);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_46343aa01b59317003e69738eaa1abba);
#
#
#             var measure_control_cfe8500110363fdf40683799b49cd22f = new L.Control.Measure(
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;primaryLengthUnit&quot;: &quot;meters&quot;,
#   &quot;secondaryLengthUnit&quot;: &quot;miles&quot;,
#   &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;,
#   &quot;secondaryAreaUnit&quot;: &quot;acres&quot;,
# });
#             map_46343aa01b59317003e69738eaa1abba.addControl(measure_control_cfe8500110363fdf40683799b49cd22f);
#
#             // Workaround for using this plugin with Leaflet&gt;=1.8.0
#             // https://github.com/ljagis/leaflet-measure/issues/171
#             L.Control.Measure.include({
#                 _setCaptureMarkerIcon: function () {
#                     // disable autopan
#                     this._captureMarker.options.autoPanOnFocus = false;
#                     // default function
#                     this._captureMarker.setIcon(
#                         L.divIcon({
#                             iconSize: this._map.getSize().multiplyBy(2)
#                         })
#                     );
#                 },
#             });
#
#
#
#             var feature_group_96240f16c57f5c9228ddf64bfc0dddba = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9331e046cc6fc1c9a8260ef2cc8ba1c2 = L.marker(
#                 [10.7758, 106.7009],
#                 {
# }
#             ).addTo(feature_group_96240f16c57f5c9228ddf64bfc0dddba);
#
#
#             var icon_a41e0397d7f248326d2211360765e0bf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_62239b80f21155b153beb197a8885047 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10282e6f716157792fd6a3cee6715aff = $(`&lt;div id=&quot;html_10282e6f716157792fd6a3cee6715aff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;KHO TỔNG TRUNG TÂM&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_62239b80f21155b153beb197a8885047.setContent(html_10282e6f716157792fd6a3cee6715aff);
#
#
#
#         marker_9331e046cc6fc1c9a8260ef2cc8ba1c2.bindPopup(popup_62239b80f21155b153beb197a8885047)
#         ;
#
#
#
#
#                 marker_9331e04

# %%
#23.14
import folium
from folium.plugins import TimestampedGeoJson
import numpy as np
from datetime import datetime, timedelta
origin = [10.7758, 106.7009]
destinations = [
    {"id": "Xe_1", "coords": [10.7626, 106.6602], "color": "blue"},
    {"id": "Xe_2", "coords": [10.8000, 106.7500], "color": "red"},
    {"id": "Xe_3", "coords": [10.7500, 106.7200], "color": "green"}
]
start_time = datetime(2026, 4, 19, 8, 0, 0)
def create_route(start, end, steps=15):
    lats = np.linspace(start[0], end[0], steps)
    lons = np.linspace(start[1], end[1], steps)
    return list(zip(lats, lons))
features = []
for d in destinations:
    route = create_route(origin, d["coords"])
    for i, (lat, lon) in enumerate(route):
        features.append({
            "type": "Feature",
            "geometry": {
                "type": "Point",
                "coordinates": [lon, lat]
            },
            "properties": {
                "time": (start_time + timedelta(minutes=i)).isoformat(),
                "icon": "circle",
                "style": {"color": d["color"]},
                "popup": d["id"]
            }
        })
m = folium.Map(location=origin, zoom_start=13)
folium.Marker(
    origin,
    popup="KHO DC",
    icon=folium.Icon(color="black")
).add_to(m)
TimestampedGeoJson(
    {
        "type": "FeatureCollection",
        "features": features
    },
    period="PT1M",
    add_last_point=True,
    auto_play=True,
    loop=True,
    max_speed=2
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8c0f482fbb87749cbc61dc966dad9ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/3.7.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8c0f482fbb87749cbc61dc966dad9ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e8c0f482fbb87749cbc61dc966dad9ba = L.map(
#                 &quot;map_e8c0f482fbb87749cbc61dc966dad9ba&quot;,
#                 {
#                     center: [10.7758, 106.7009],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83ae76f196b7fa3569683af3f80fc94c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_83ae76f196b7fa3569683af3f80fc94c.addTo(map_e8c0f482fbb87749cbc61dc966dad9ba);
#
#
#             var marker_eed40e7371338ff1dace967c0cb152c2 = L.marker(
#                 [10.7758, 106.7009],
#                 {
# }
#             ).addTo(map_e8c0f482fbb87749cbc61dc966dad9ba);
#
#
#             var icon_287611b963859d0517166f49135a741c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;black&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_700362a2bad79ea9499d23bfda05ba00 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49eb2f08d1f5a503e6e6d19159eaba20 = $(`&lt;div id=&quot;html_49eb2f08d1f5a503e6e6d19159eaba20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KHO DC&lt;/div&gt;`)[0];
#                 popup_700362a2bad79ea9499d23bfda05ba00.setContent(html_49eb2f08d1f5a503e6e6d19159eaba20);
#
#
#
#         marker_eed40e7371338ff1dace967c0cb152c2.bindPopup(popup_700362a2bad79ea9499d23bfda05ba00)
#         ;
#
#
#
#
#                 marker_eed40e7371338ff1dace967c0cb152c2.setIcon(icon_287611b963859d0517166f49135a741c);
#
#
#             L.Control.TimeDimensionCustom = L.Control.TimeDimension.extend({
#                 _getDisplayDateFormat: function(date){
#                     var newdate = new moment(date);
#                     console.log(newdate)
#                     return newdate.format(&quot;YYYY-MM-DD HH:mm:ss&quot;);
#                 }
#             });
#             map_e8c0f482fbb87749cbc61dc966dad9ba.timeDimension = L.timeDimension(
#                 {
#                     period: &quot;PT1M&quot;,
#                 }
#             );
#             var timeDimensionControl = new L.Control.TimeDimensionCustom(
#                 {
#   &quot;position&quot;: &quot;bottomleft&quot;,
#   &quot;minSpeed&quot;: 0.1,
#   &quot;maxSpeed&quot;: 2,
#   &quot;autoPlay&quot;: true,
#   &quot;loopButton&quot;: false,
#   &quot;timeSliderDragUpdate&quot;: false,
#   &quot;speedSlider&quot;: true,
#   &quot;playerOptions&quot;: {
#   &quot;transitionTime&quot;: 200,
#   &quot;loop&quot;: true,
#   &quot;startOver&quot;: true,
# },
# }
#             );
#             map_e8c0f482fbb87749cbc61dc966dad9ba.addControl(this.timeDimensionControl);
#
#             var geoJsonLayer = L.geoJson({&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: [{&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [106.7009, 10.7758]}, &quot;properties&quot;: {&quot;time&quot;: &quot;2026-04-19T08:00:00&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;style&quot;: {&quot;color&quot;: &quot;blue&quot;}, &quot;popup&quot;: &quot;Xe_1&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [106.6979928571428

# %%
#23.15
import folium
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd
import numpy as np
np.random.seed(42)
data = {
    "Customer_ID": range(1, 51),
    "Lat": np.random.uniform(10.73, 10.82, 50),
    "Lon": np.random.uniform(106.63, 106.75, 50),
    "Volume": np.random.randint(10, 100, 50)
}
df = pd.DataFrame(data)
total_volume = df["Volume"].sum()
optimized_lat = (df["Lat"] * df["Volume"]).sum() / total_volume
optimized_lon = (df["Lon"] * df["Volume"]).sum() / total_volume
optimized_warehouse = [optimized_lat, optimized_lon]
m = folium.Map(location=[10.776, 106.700], zoom_start=12)
heat_data = [
    [row["Lat"], row["Lon"], row["Volume"]]
    for _, row in df.iterrows()
]
HeatMap(heat_data,name="Mật độ nhu cầu (Heatmap)",radius=15,blur=10).add_to(m)
customer_group = folium.FeatureGroup(name="Danh sách khách hàng")
marker_cluster = MarkerCluster().add_to(customer_group)
for _, row in df.iterrows():
    folium.CircleMarker(
        location=[row["Lat"], row["Lon"]],
        radius=4,
        color="blue",
        fill=True,
        fill_color="blue",
        fill_opacity=0.7,
        popup=f"KH: {row['Customer_ID']}<br>Sản lượng: {row['Volume']}"
    ).add_to(marker_cluster)
customer_group.add_to(m)
folium.Marker(
    optimized_warehouse,
    popup="Kho tối ưu",
    icon=folium.Icon(color="red", icon="home")
).add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_032151c59456b04e572a40f92511a618 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_032151c59456b04e572a40f92511a618&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_032151c59456b04e572a40f92511a618 = L.map(
#                 &quot;map_032151c59456b04e572a40f92511a618&quot;,
#                 {
#                     center: [10.776, 106.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e3b2383160cdac069fd6857225e6fc6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e3b2383160cdac069fd6857225e6fc6.addTo(map_032151c59456b04e572a40f92511a618);
#
#
#             var heat_map_bfb71216bf6095e864761cb24fcea357 = L.heatLayer(
#                 [[10.763708610696263, 106.74635015533174, 72.0], [10.815564287576892, 106.72301593880333, 61.0], [10.795879454763027, 106.7427398729877, 13.0], [10.783879263577735, 106.73737928205132, 32.0], [10.744041677639819, 106.70174799745733, 24.0], [10.744039506830259, 106.74062490820278, 52.0], [10.735227525095139, 106.64061910024623, 38.0], [10.807955853119745, 106.6535179434903, 45.0], [10.784100351056889, 106.63542727466925, 22.0], [10.793726532001644, 106.66903963969159, 41.0], [10.731852604486622, 106.67664127476273, 80.0], [10.81729188669458, 106.66256188381287, 68.0], [10.804919837672038, 106.72944850109823, 95.0], [10.749110519961045, 106.67281039920323, 37.0], [10.74636424704864, 106.66371214116248, 75.0], [10.746506405886809, 106.69512352997899, 51.0], [10.757381801866359, 106.64691090699696, 54.0], [10.777228078846901, 106.72626363769048, 71.0], [10.76887505167779, 106.63894607724157, 66.0], [10.756210622617823, 106.74842643239207, 15.0], [10.785066760525014, 106.7226693723156, 37.0], [10.742554447458684, 106.6538458817841, 37.0], [10.75629301836817, 106.63066265405483, 53.0], [10.762972565896433, 106.72785537141458, 93.0], [10.771046298579533, 106.71482288126171, 39.0], [10.800665836525372, 106.71748086016491, 71.0], [10.747970640394254, 106.72255244160232, 84.0], [10.776281099457226, 106.63888535820809, 98.0], [10.783317311197584, 106.67301588742531, 71.0], [10.7341805371448, 106.64390428714302, 10.0], [10.784679036671129, 106.73357241110507, 36.0], [10.745347171131856, 106.70479577521931, 71.0], [10.735854643368675, 106.66970776298231, 86.0], [10.8153996983528, 106.63762700203432, 12.0], [10.81690688297671, 106.66731787860587, 79.0], [10.802755761330483, 106.6690219986432, 81.0], [10.757415239225605, 106.71755274140057, 36.0], [10.738790490260575, 106.70650689656263, 18.0], [10.791580972386095, 106.73646552910915, 71.0], [10.769613724436564, 106.68666579101944, 46.0], [10.74098344113603, 106.64435130951259, 60.0], [10.774565921910014, 106.71558937446676, 53.0], [10.73309496690037, 106.72129420583403, 33.0], [10.811838836187091, 106.69735326370834, 88.0], [10.753290198344002, 106.72251606159455, 68.0], [10.789627005591859, 106.68925547156373, 41.0], [10.758053996848048, 106.69272793952584, 97.0], [10.776806121906004, 106.68130492220303, 61.0], [10.779203925140896, 106.63305029520929, 71.0], [10.746636900997299, 106.6429469712392, 67.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 15,
#   &quot;blur&quot;: 10,
# }
#             );
#
#
#             heat_map_bfb71216bf6095e864761cb24fcea357.addTo(map_032151c59456b04e572a40f92511a618);
#
#
#             var feature_group_a28c894cc9d8d1e3c64fd215b9181339 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cluster_50bee143d6a175f5cb64b9dfe20bb248 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_a966f2fc9dcd7f21ed81e67df0efa795 = L.circleMarker(
#                 [10.763708610696263, 106.74635015533174],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot

# %%
#23.4
import folium
import pandas as pd
import json

geo_data_path = "/content/district-boundary-hcm-city (1) (1).geojson"

try:
    with open(geo_data_path, 'r', encoding='utf-8') as f:
        geo_data = json.load(f)

    districts = [f['properties'].get('name', f['properties'].get('District', f'District {i}'))
                 for i, f in enumerate(geo_data['features'])]
    df = pd.DataFrame({
        'Ten khu vuc': districts,
        'Doanh thu': [i * 10 + 100 for i in range(len(districts))]
    })

    m = folium.Map(location=[10.776, 106.700], zoom_start=11)

    folium.Choropleth(
        geo_data=geo_data,
        data=df,
        columns=["Ten khu vuc", "Doanh thu"],
        key_on="feature.properties.name",
        fill_color="YlOrRd",
        fill_opacity=0.7,
        line_opacity=0.2,
        legend_name="Doanh thu (triệu đồng)"
    ).add_to(m)

    display(m)

except Exception as e:
    print(f"Lỗi: {e}")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_304fb313fe48cd0e2de65a6e0f14d4b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_304fb313fe48cd0e2de65a6e0f14d4b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_304fb313fe48cd0e2de65a6e0f14d4b9 = L.map(
#                 &quot;map_304fb313fe48cd0e2de65a6e0f14d4b9&quot;,
#                 {
#                     center: [10.776, 106.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be9d8e0ab930e3bcf82ce5af0650e89c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be9d8e0ab930e3bcf82ce5af0650e89c.addTo(map_304fb313fe48cd0e2de65a6e0f14d4b9);
#
#
#             var choropleth_a46318eb0136e5c02909b7e460b0f02a = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_a7ebd0872a7769c588d59553125bd904_styler(feature) {
#             switch(feature.id) {
#                 case 3850184: case 3797166:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 2587287: case 3819816:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 2778323: case 3820432:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 2764875: case 3877245:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case 3799817: case 3851694:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_a7ebd0872a7769c588d59553125bd904_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_a7ebd0872a7769c588d59553125bd904 = L.geoJson(null, {
#                 onEachFeature: geo_json_a7ebd0872a7769c588d59553125bd904_onEachFeature,
#
#                 style: geo_json_a7ebd0872a7769c588d59553125bd904_styler,
#             ...{
# }
#         });
#
#         function geo_json_a7ebd0872a7769c588d59553125bd904_add (data) {
#             geo_json_a7ebd0872a7769c588d59553125bd904
#                 .addData(data);
#         }
#             geo_json_a7ebd0872a7769c588d59553125bd904_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[106.6934435, 10.7221295], [106.694747, 10.7227936], [106.6949401, 10.7228568], [106.6951118, 10.722841], [106.6972254, 10.7223666], [106.6973863, 10.7222823], [106.6974936, 10.7221136], [106.6992424, 10.7168165], [106.6988615, 10.7164739], [106.6985021, 10.7162841], [106.6981159, 10.7163948], [106.6975955, 10.7165529], [106.6970913, 10.7168218], [106.6963993, 10.7173119], [106.6959004, 10.71776], [106.6956161, 10.7181816], [106.6954068, 10.7185506], [106.6951869, 10.7190197], [106.6951011, 10.7196153], [106.6949938, 10.7199684], [106.694865, 10.7203268], [106.6946451, 10.7207959], [106.694275, 10.7212756], [106.6939102, 10.7216814], [106.6935776, 10.7219977], [106.6934435, 10.7221295]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: 3850184, &quot;properties&quot;: {&quot;SRID&quot;: &quot;4326&quot;, &quot;admin_level&quot;: 5, &quot;id&quot;: 3850184, &quot;localname&quot;: &quot;Khu \u0111\u00f4 th\u1ecb Nam S\u00e0i G\u00f2n&quot;, &quot;name&quot;: &quot;Saigon South&quot;, &quot;rpath&quot;: [&quot;3850184&quot;, &quot;1973756&quot;, &quot;49915&quot;, &quot;0&quot;], &quot;tags&quot;: {&quot;admin_level&quot;: &quot;5&quot;, &quot;boundary&quot;: &quot;administrative&quot;, &quot;name&quot;: &quot;Khu \u0111\u00f4 th\u1ecb Nam S\u00e0i G\u00f2n&quot;, &quot;name:en&quot;: &quot;Saigon South&quot;, &quot;name:vi&quot;: &quot;Khu Nam S\u00e0i G\u00f2n&quot;
